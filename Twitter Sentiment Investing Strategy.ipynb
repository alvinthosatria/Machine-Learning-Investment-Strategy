# %% [markdown]
# # Twitter Sentiment Investing Strategy

# %% [markdown]
# ## 1. Load Twitter Sentiment Data

# %% [markdown]
# - Load the twitter sentiment dataset, set the index, calculat engagement ratio and filter out stocks with no significant twitter activity.

# %%
# !pip install pandas
# !pip install pandas_ta
# !pip install matplotlib
# !pip install statsmodels
# !pip install pandas_datareader
# !pip install datetime
# !pip install yfinance
# !pip install scikit-learn
# !pip install PyPortfolioOpt
# Out:
# Requirement already satisfied: pandas in c:\python310\lib\site-packages (2.2.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\python310\lib\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas_ta in c:\python310\lib\site-packages (0.3.14b0)
# Requirement already satisfied: pandas in c:\python310\lib\site-packages (from pandas_ta) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas->pandas_ta) (2023.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\python310\lib\site-packages (from pandas->pandas_ta) (1.26.3)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas->pandas_ta) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.16.0)
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\python310\lib\site-packages (3.8.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python310\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: numpy<2,>=1.21 in c:\python310\lib\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: pillow>=8 in c:\python310\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python310\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: six>=1.5 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: statsmodels in c:\python310\lib\site-packages (0.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in c:\python310\lib\site-packages (from statsmodels) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from statsmodels) (23.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\python310\lib\site-packages (from statsmodels) (1.12.0)
# Requirement already satisfied: patsy>=0.5.4 in c:\python310\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: numpy<2,>=1.22.3 in c:\python310\lib\site-packages (from statsmodels) (1.26.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2023.4)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2023.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\users\alvin\appdata\roaming\python\python310\site-packages (from patsy>=0.5.4->statsmodels) (1.16.0)
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas_datareader in c:\python310\lib\site-packages (0.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\python310\lib\site-packages (from pandas_datareader) (2.31.0)
# Requirement already satisfied: pandas>=0.23 in c:\python310\lib\site-packages (from pandas_datareader) (2.2.0)
# Requirement already satisfied: lxml in c:\python310\lib\site-packages (from pandas_datareader) (5.1.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\python310\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas>=0.23->pandas_datareader) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas>=0.23->pandas_datareader) (2023.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python310\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python310\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2023.11.17)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.6)
# Requirement already satisfied: six>=1.5 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.16.0)
# Requirement already satisfied: datetime in c:\python310\lib\site-packages (5.4)
# Requirement already satisfied: pytz in c:\python310\lib\site-packages (from datetime) (2023.4)
# Requirement already satisfied: zope.interface in c:\python310\lib\site-packages (from datetime) (6.1)
# Requirement already satisfied: setuptools in c:\python310\lib\site-packages (from zope.interface->datetime) (63.2.0)
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: yfinance in c:\python310\lib\site-packages (0.2.36)
# Requirement already satisfied: numpy>=1.16.5 in c:\python310\lib\site-packages (from yfinance) (1.26.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\python310\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\python310\lib\site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\python310\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: pandas>=1.3.0 in c:\python310\lib\site-packages (from yfinance) (2.2.0)
# Requirement already satisfied: pytz>=2022.5 in c:\python310\lib\site-packages (from yfinance) (2023.4)
# Requirement already satisfied: lxml>=4.9.1 in c:\python310\lib\site-packages (from yfinance) (5.1.0)
# Requirement already satisfied: requests>=2.31 in c:\python310\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: html5lib>=1.1 in c:\python310\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\python310\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\python310\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: soupsieve>1.2 in c:\python310\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: webencodings in c:\python310\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\lib\site-packages (from requests>=2.31->yfinance) (2023.11.17)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python310\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python310\lib\site-packages (from requests>=2.31->yfinance) (2.2.0)
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\python310\lib\site-packages (1.4.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\python310\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python310\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\python310\lib\site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\python310\lib\site-packages (from scikit-learn) (1.12.0)
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: PyPortfolioOpt in c:\python310\lib\site-packages (1.5.5)
# Requirement already satisfied: scipy<2.0,>=1.3 in c:\python310\lib\site-packages (from PyPortfolioOpt) (1.12.0)
# Requirement already satisfied: pandas>=0.19 in c:\python310\lib\site-packages (from PyPortfolioOpt) (2.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in c:\python310\lib\site-packages (from PyPortfolioOpt) (1.26.3)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in c:\python310\lib\site-packages (from PyPortfolioOpt) (1.4.2)
# Requirement already satisfied: pybind11 in c:\python310\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (2.11.1)
# Requirement already satisfied: osqp>=0.6.2 in c:\python310\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.6.3)
# Requirement already satisfied: clarabel>=0.5.0 in c:\python310\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.6.0)
# Requirement already satisfied: scs>=3.0 in c:\python310\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (3.2.4.post1)
# Requirement already satisfied: ecos>=2 in c:\python310\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (2.0.12)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2023.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2023.4)
# Requirement already satisfied: qdldl in c:\python310\lib\site-packages (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.1.7.post0)
# Requirement already satisfied: six>=1.5 in c:\users\alvin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->PyPortfolioOpt) (1.16.0)
# [notice] A new release of pip available: 22.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import yfinance as yf
import os

plt.style.use('ggplot')

data_folder = r'C:\Users\alvin\AlgoTrading_Machine_Learning_2023'

sentiment_df = pd.read_csv(os.path.join(data_folder, 'sentiment_data.csv'))

sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])

sentiment_df = sentiment_df.set_index(['date', 'symbol'])

sentiment_df['engagement_ratio'] = sentiment_df['twitterComments']/sentiment_df['twitterLikes']

sentiment_df = sentiment_df[(sentiment_df['twitterLikes']>20)&(sentiment_df['twitterComments']>10)]

sentiment_df
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
#            BA              61.0             55.0         342.0
# ...                         ...              ...           ...
# 2023-01-04 T              184.0           3409.0       14271.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment  engagement_ratio
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN          0.119590
#            AMD              1645270.0               NaN          0.228891
#            AMZN             5590695.0               NaN          0.101396
#            ATVI             1310715.0               NaN          0.274809
#            BA                425847.0               NaN          0.160819
# ...                               ...               ...               ...
# 2023-01-04 T                 884935.0          0.590457          0.238876
#            TSLA            55464921.0          0.543057          0.141893
#            TSN                57207.0          0.561900          0.365217
#            V                 139835.0          0.567286          0.169611
#            XOM               483389.0          0.588914          0.180589
#
# [25375 rows x 6 columns]

# %% [markdown]
# # 2. Aggregate Monthly and calculate average sentiment for the month

# %% [markdown]
# - Aggregate on a monthly level and calculate average monthly metric, for the one we choose.

# %%
aggregated_df = (sentiment_df.reset_index('symbol').groupby([pd.Grouper(freq='ME'), 'symbol'])
                    [['engagement_ratio']].mean())

aggregated_df['rank'] = (aggregated_df.groupby(level=0)['engagement_ratio']
                         .transform(lambda x: x.rank(ascending=False)))

aggregated_df
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-11-30 AAL             0.203835  37.0
#            AAPL            0.256318  23.0
#            ABBV            0.244677  26.0
#            ABT             0.313368  14.0
#            AES             0.864613   2.0
# ...                             ...   ...
# 2023-01-31 TMO             0.333313  19.0
#            TSLA            0.151992  72.0
#            TSN             0.280553  30.0
#            V               0.194045  60.0
#            XOM             0.217904  53.0
#
# [1109 rows x 2 columns]

# %% [markdown]
# # 3. Select Top 5 Stocks based on their cross-sectional ranking for each month

# %% [markdown]
# - Select top 5 stocks by rank for each month and fix the date to start at beginning of next month.

# %%
filtered_df = aggregated_df[aggregated_df['rank']<6].copy()

filtered_df = filtered_df.reset_index(level=1)

filtered_df.index = filtered_df.index+pd.DateOffset(1)

filtered_df = filtered_df.reset_index().set_index(['date', 'symbol'])

filtered_df.head(20)
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-12-01 AES             0.864613   2.0
#            FCX             0.626323   5.0
#            MNST            0.699721   3.0
#            OXY             2.147741   1.0
#            SLB             0.647374   4.0
# 2022-01-01 D               0.801994   5.0
#            FCX             0.841220   4.0
#            L               6.507246   1.0
#            LUV             1.303215   2.0
#            MA              0.883401   3.0
# 2022-02-01 AMD             0.715556   4.0
#            D               1.136678   1.0
#            FCX             0.655237   5.0
#            LUV             1.035258   2.0
#            MA              0.729063   3.0
# 2022-03-01 FCX             1.138332   2.0
#            GILD            0.530886   5.0
#            LUV             1.574377   1.0
#            MRO             0.581748   4.0
#            OXY             1.025579   3.0

# %% [markdown]
# ## 4. Extract the stocks to form portfolios with at the start of each new month

# %% [markdown]
# - Create a dictionary containing start of month and corresponded selected stocks.

# %%
dates = filtered_df.index.get_level_values('date').unique().tolist()

fixed_dates = {}

for d in dates:
    
    fixed_dates[d.strftime('%Y-%m-%d')] = filtered_df.xs(d, level=0).index.tolist()
    
fixed_dates
# Out:
# {'2021-12-01': ['AES', 'FCX', 'MNST', 'OXY', 'SLB'],
#  '2022-01-01': ['D', 'FCX', 'L', 'LUV', 'MA'],
#  '2022-02-01': ['AMD', 'D', 'FCX', 'LUV', 'MA'],
#  '2022-03-01': ['FCX', 'GILD', 'LUV', 'MRO', 'OXY'],
#  '2022-04-01': ['A', 'CRM', 'PFE', 'PM', 'STZ'],
#  '2022-05-01': ['AMD', 'CRM', 'CVX', 'J', 'KEY'],
#  '2022-06-01': ['AMD', 'DD', 'FCX', 'KEY', 'LMT'],
#  '2022-07-01': ['CB', 'CRM', 'DD', 'FCX', 'STZ'],
#  '2022-08-01': ['A', 'DD', 'JPM', 'REGN', 'STZ'],
#  '2022-09-01': ['ABT', 'DIS', 'L', 'META', 'MRNA'],
#  '2022-10-01': ['J', 'KEY', 'L', 'META', 'MU'],
#  '2022-11-01': ['A', 'DD', 'FCX', 'J', 'META'],
#  '2022-12-01': ['AEP', 'AES', 'DD', 'J', 'STZ'],
#  '2023-01-01': ['A', 'AES', 'DAL', 'J', 'KEY'],
#  '2023-02-01': ['A', 'AES', 'BIIB', 'FCX', 'MDT']}

# %% [markdown]
# ## 5. Download fresh stock prices for only selected/shortlisted stocks

# %%
stocks_list = sentiment_df.index.get_level_values('symbol').unique().tolist()

prices_df = yf.download(tickers=stocks_list,
                        start='2021-01-01',
                        end='2023-03-01')

prices_df
# Out:
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [                       0%%                      ]c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*                      2%%                      ]  2 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*                      2%%                      ]  2 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [****                   8%%                      ]  7 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [****                   9%%                      ]  8 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*****                 11%%                      ]  9 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [******                12%%                      ]  10 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [******                13%%                      ]  11 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [******                13%%                      ]  11 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*******               15%%                      ]  13 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********             19%%                      ]  16 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********            20%%                      ]  17 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********            21%%                      ]  18 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [***********           22%%                      ]  19 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [************          25%%                      ]  21 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*************         28%%                      ]  24 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**************        29%%                      ]  25 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [***************       31%%                      ]  26 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [***************       32%%                      ]  27 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [****************      34%%                      ]  29 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*****************     36%%                      ]  31 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*******************   39%%                      ]  33 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*******************   40%%                      ]  34 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [********************  41%%                      ]  35 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [********************  42%%                      ]  36 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [********************  42%%                      ]  36 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************48%%                      ]  41 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************49%%                      ]  42 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************51%%                      ]  43 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************53%%                      ]  45 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************54%%                      ]  46 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************58%%**                    ]  49 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************59%%**                    ]  50 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************60%%***                   ]  51 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************61%%***                   ]  52 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************62%%****                  ]  53 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************64%%*****                 ]  54 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************65%%*****                 ]  55 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************65%%*****                 ]  55 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************71%%********              ]  60 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************72%%*********             ]  61 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************73%%*********             ]  62 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************75%%**********            ]  64 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************76%%**********            ]  65 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************79%%************          ]  67 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************81%%*************         ]  69 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************82%%*************         ]  70 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************82%%*************         ]  70 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************88%%****************      ]  75 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************91%%******************    ]  77 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************92%%******************    ]  78 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************93%%*******************   ]  79 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************95%%********************  ]  81 of 85 completedc:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  85 of 85 completed
#
# 1 Failed download:
# ['ATVI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Price        Adj Close                                                         \
# Ticker               A    AAL         AAP        AAPL        ABBV         ABT
# Date
# 2021-01-04  116.384743  15.13  145.845108  127.164177   92.173615  103.105194
# 2021-01-05  117.336319  15.43  145.687500  128.736359   93.126740  104.380890
# 2021-01-06  120.553947  15.52  154.104172  124.402931   92.322258  104.163551
# 2021-01-07  123.761803  15.38  155.420395  128.647964   93.310364  105.174667
# 2021-01-08  124.644684  15.13  157.635818  129.758347   93.800049  105.467621
# ...                ...    ...         ...         ...         ...         ...
# 2023-02-22  141.055115  15.56  140.077377  148.308395  144.812668  100.645615
# 2023-02-23  142.167023  15.87  138.507080  148.796417  146.158249  100.508400
# 2023-02-24  140.181458  15.56  135.425049  146.117294  146.773361   98.459999
# 2023-02-27  141.154388  15.63  137.161133  147.322372  148.282318   97.783730
# 2023-02-28  140.945892  15.98  141.384323  146.814438  147.917084   99.694916
#
# Price                                                    ...   Volume  \
# Ticker            AEP        AES         ALB        AMD  ...      RCL
# Date                                                     ...
# 2021-01-04  73.126465  21.144060  149.119370  92.300003  ...  5732800
# 2021-01-05  73.027809  21.853712  159.182480  92.769997  ...  4029500
# 2021-01-06  73.610741  22.727133  171.072540  90.330002  ...  3612500
# 2021-01-07  71.646713  22.499680  179.767838  95.160004  ...  3993700
# 2021-01-08  71.009964  23.127455  179.865524  94.580002  ...  3104200
# ...               ...        ...         ...        ...  ...      ...
# 2023-02-22  88.074539  24.488308  244.324463  76.610001  ...  2044600
# 2023-02-23  87.967865  24.488308  251.660645  79.750000  ...  2066600
# 2023-02-24  87.696327  24.420795  247.367966  78.089996  ...  2875100
# 2023-02-27  87.347214  23.996422  254.803268  78.769997  ...  2459700
# 2023-02-28  85.310707  23.803526  252.116653  78.580002  ...  3662300
#
# Price                                                                          \
# Ticker         REGN       SLB      STZ         T      TMO       TSLA      TSN
# Date
# 2021-01-04   911100   8743400  1202600  86700816  2220400  145914600  2177400
# 2021-01-05   797700  16256600  1530200  83054520  2046700   96735600  2297100
# 2021-01-06  1434700  19456300  1861700  73455520  2112300  134100000  1942200
# 2021-01-07  1126600  14502400  2537100  71265359  2144400  154496700  2969400
# 2021-01-08  1018800  11951900  1595400  72471656  2221700  225166500  2672400
# ...             ...       ...      ...       ...      ...        ...      ...
# 2023-02-22   415500   9181100  1092200  25308800  1705300  191828500  4217700
# 2023-02-23   553300   6324500   979700  24845800  1160200  146360000  3403500
# 2023-02-24   525900   8458700   702900  29138100   852600  142228100  2439300
# 2023-02-27   557100   6287000   608200  22981100  1110600  161028300  3922200
# 2023-02-28   622700  10634200  1136900  34154800  1188800  153144900  3556300
#
# Price
# Ticker             V       XOM
# Date
# 2021-01-04  10318300  27764700
# 2021-01-05   6869700  44035100
# 2021-01-06   7206200  36484800
# 2021-01-07  10967900  29528100
# 2021-01-08   6513000  28628200
# ...              ...       ...
# 2023-02-22   4621800  13973800
# 2023-02-23   5533800  11289400
# 2023-02-24   4414400  14351000
# 2023-02-27   4255300  11710500
# 2023-02-28   5385400  18107000
#
# [542 rows x 510 columns]

# %% [markdown]
# ## 6. Calculate Portfolio Returns with monthly rebalancing

# %%
returns_df = np.log(prices_df['Adj Close'].dropna(axis=1)).diff().dropna()

portfolio_df = pd.DataFrame()

for start_date in fixed_dates.keys():
    
    end_date = (pd.to_datetime(start_date)+pd.offsets.MonthEnd()).strftime('%Y-%m-%d')
    
    cols = fixed_dates[start_date]
    
    temp_df = returns_df[start_date:end_date][cols].mean(axis=1).to_frame('portfolio_return')
    
    portfolio_df = pd.concat([portfolio_df, temp_df], axis=0)
    
portfolio_df
# Out:
#             portfolio_return
# Date
# 2021-12-01         -0.016417
# 2021-12-02          0.024872
# 2021-12-03         -0.007711
# 2021-12-06          0.023926
# 2021-12-07          0.030547
# ...                      ...
# 2023-02-22         -0.007870
# 2023-02-23         -0.007323
# 2023-02-24         -0.009463
# 2023-02-27         -0.001871
# 2023-02-28          0.001403
#
# [312 rows x 1 columns]

# %% [markdown]
# ## 7. Download NASDAQ/QQQ prices and calculate returns to compare to our strategy

# %%
qqq_df = yf.download(tickers='QQQ',
                     start='2021-01-01',
                     end='2023-03-01')

qqq_ret = np.log(qqq_df['Adj Close']).diff().to_frame('nasdaq_return')

portfolio_df = portfolio_df.merge(qqq_ret,
                                  left_index=True,
                                  right_index=True)
# Out:
# c:\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed

# %%
portfolios_cumulative_return = np.exp(np.log1p(portfolio_df).cumsum()).sub(1)

portfolios_cumulative_return.plot(figsize=(16,6))

plt.title('Twitter Engagement Ratio Strategy Return Over Time')

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1))

plt.ylabel('Return')

plt.show()
